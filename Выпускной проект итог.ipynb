# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Привет Андрей!</b>
#
# Меня зовут  Евгений Арзамасцев, я твой тимлид по этому проекту. Буду проверять следующие этапы твоей работы:
# <p> * План работ и уточняющие вопросы
# <p> * Основной код разработки модели
# <p> * Отчет о проделанной работе
#
#  Предлагаю общаться на «ты» :) Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать отличным специалистом по Data Science. Ты уже проделал большую работу над проектами этого курса. Сейчас у тебя Финальный Спринт - дипломная работа. Моя цель - помочь тебе сделать ее максимально качественно, чтобы было не стыдно ссылаться на данную работу в своем резюме!
#
# Ниже ты найдешь мои комментарии - **пожалуйста, не перемещай, не изменяй и не удаляй их**. Увидев у тебя ошибку, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой начальник будет поступать так же, а я пытаюсь подготовить тебя именно к таким ситуациям. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий тимлида ❌:</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий тимлида ⚠️:</b> Так выделены небольшие замечания. Я надеюсь, что их ты тоже учтешь - твой проект от этого станет только лучше. Но настаивать на их отработке не буду.
#
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий тимлида ✔️:</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом.** Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# # Прозноз оттока клиентов у «Ниединогоразрыва.ком»

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# ### Цель

# %% [markdown]
# Научить модель прогнозировать уход клиента.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента_3:</b> Поменял цель проекта.</div>

# %% [markdown]
# ### Описание услуг компании

# %% [markdown]
# Оператор предоставляет два основных типа услуг:
#
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 2. Интернет. Подключение может быть двух типов: через телефонную линию (DSL*,* от англ. *digital subscriber line*, «цифровая абонентская линия») или оптоволоконный кабель (*Fiber optic*).
#
# Также доступны такие услуги:
#
# - Интернет-безопасность: антивирус (*DeviceProtection*) и блокировка небезопасных сайтов (*OnlineSecurity*);
# - Выделенная линия технической поддержки (*TechSupport*);
# - Облачное хранилище файлов для резервного копирования данных (*OnlineBackup*);
# - Стриминговое телевидение (*StreamingTV*) и каталог фильмов (*StreamingMovies*).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Данные состоят из файлов, полученных из разных источников:
#
# - `contract.csv` — информация о договоре;
# - `personal.csv` — персональные данные клиента;
# - `internet.csv` — информация об интернет-услугах;
# - `phone.csv` — информация об услугах телефонии.
#
# Во всех файлах столбец `customerID` содержит код клиента.
#
# Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# ### План работы

# %% [markdown]
# 1. Загрузить и подготовить данные.
# 2. Выполнить разведочный анализ: составить портрет уходящего клиента.
# 3. Сделать тестовую выборку размером 25%. Обучить модели с разными гиперпараметрами и выбрать наилучшую.
# 4. Проверить данные на тестовой выборке.
# 5. Сделать отчет по работе.

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида ✔️:**</b>
#
# 1. В описательной части есть название, общее описание проекта, цель проекта. Есть даже короткое описание исходных данных. Отлично!
#
# 2. Есть план работ. Указанны все основные этапы исследования! Вижу что понимаешь что предстоит делать, уверен инструментарий тоже подберешь верно!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>**Комментарий тимлида ⚠️:**</b>
#
# Данное исследование можно будет приложить к портфолио и показывать потенциальным работодателям на собесах. По этому предлагаю сразу же оформлять его в соответствии с требованиями к исследованию. В описательной части не хватает:
#
# - хорошего названия проекта (текущее название сильно похоже на название учебной работы)
# - четко сформулированной цели проекта
#
# Касаемо цели - я рекомендую ее немного изменить и привести в соответствие с требованиями SMART. Если интересно - почитай вот тут https://www.carrotquest.io/blog/smart-goal/. Можно привести SMARTированную цель проекта уже потом, на следующем этапе.
#
# Рекомендую доработать этот раздел.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Название поменял. Цель в течение проекта доработаю.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v2 ✔️:**</b>
#
# 👍
# </div>

# %% [markdown]
# ## Загрузка и подготовка данных

# %%
# !pip install -q phik
# !pip install skimpy

# %%
import pandas as pd
import numpy as np
from skimpy import clean_columns
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.metrics import recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import TimeSeriesSplit, cross_val_score, StratifiedKFold, GridSearchCV, cross_validate, KFold
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn import linear_model
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_auc_score,roc_curve,confusion_matrix,accuracy_score
import lightgbm as lgb
from lightgbm import LGBMClassifier
from lightgbm import plot_importance
from numpy.random import RandomState
from catboost import CatBoostClassifier

import phik
from phik.report import plot_correlation_matrix
from phik import report
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# C:\Users\ASUS\anaconda3\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# C:\Users\ASUS\anaconda3\lib\site-packages\dask\dataframe\utils.py:369: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)

# %%
try:
    df_contract = pd.read_csv('/datasets/final_provider/contract.csv')
except FileNotFoundError:
    df_contract = pd.read_csv('C:\\Users\\ASUS\\OneDrive\\Рабочий стол\\Аналитик Big Data. Яндекс\\Выпускной проект\\final_provider\\contract.csv')
df_contract.head(10)
# Out:
#    customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
# 5  9305-CDSKC  2019-03-01  2019-11-01 00:00:00  Month-to-month
# 6  1452-KIOVK  2018-04-01                   No  Month-to-month
# 7  6713-OKOMC  2019-04-01                   No  Month-to-month
# 8  7892-POOKP  2017-07-01  2019-11-01 00:00:00  Month-to-month
# 9  6388-TABGU  2014-12-01                   No        One year
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида ✔️:**</b>
#
# Очень хорошо, что используешь конструкцию try-except!
# </div>

# %%
try:
    df_personal = pd.read_csv('/datasets/final_provider/personal.csv')
except FileNotFoundError:
    df_personal = pd.read_csv('C:\\Users\\ASUS\\OneDrive\\Рабочий стол\\Аналитик Big Data. Яндекс\\Выпускной проект\\final_provider\\personal.csv')
df_personal.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No
# 5  9305-CDSKC  Female              0      No         No
# 6  1452-KIOVK    Male              0      No        Yes
# 7  6713-OKOMC  Female              0      No         No
# 8  7892-POOKP  Female              0     Yes         No
# 9  6388-TABGU    Male              0      No        Yes

# %%
try:
    df_internet = pd.read_csv('/datasets/final_provider/internet.csv')
except FileNotFoundError:
    df_internet = pd.read_csv('C:\\Users\\ASUS\\OneDrive\\Рабочий стол\\Аналитик Big Data. Яндекс\\Выпускной проект\\final_provider\\internet.csv')
df_internet.head(10)
# Out:
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
# 5  9305-CDSKC     Fiber optic             No           No              Yes
# 6  1452-KIOVK     Fiber optic             No          Yes               No
# 7  6713-OKOMC             DSL            Yes           No               No
# 8  7892-POOKP     Fiber optic             No           No              Yes
# 9  6388-TABGU             DSL            Yes          Yes               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# ...

# %%
try:
    df_phone = pd.read_csv('/datasets/final_provider/phone.csv')
except FileNotFoundError:
    df_phone = pd.read_csv('C:\\Users\\ASUS\\OneDrive\\Рабочий стол\\Аналитик Big Data. Яндекс\\Выпускной проект\\final_provider\\phone.csv')
df_phone.head(10)
# Out:
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes
# 5  7892-POOKP           Yes
# 6  6388-TABGU            No
# 7  9763-GRSKD            No
# 8  7469-LKBCI            No
# 9  8091-TTVAX           Yes

# %%
df_contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB

# %%
df_personal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
df_internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
#  1   InternetService   5517 non-null   object
#  2   OnlineSecurity    5517 non-null   object
#  3   OnlineBackup      5517 non-null   object
#  4   DeviceProtection  5517 non-null   object
#  5   TechSupport       5517 non-null   object
#  6   StreamingTV       5517 non-null   object
#  7   StreamingMovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB

# %%
df_phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB

# %%
df = df_contract.merge(df_personal,how='inner',on='customerID').merge(df_internet,how='left',on='customerID')
df = df.merge(df_phone,how='left',on='customerID')
df.head(10)
# Out:
#    customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
# 5  9305-CDSKC  2019-03-01  2019-11-01 00:00:00  Month-to-month
# 6  1452-KIOVK  2018-04-01                   No  Month-to-month
# 7  6713-OKOMC  2019-04-01                   No  Month-to-month
# 8  7892-POOKP  2017-07-01  2019-11-01 00:00:00  Month-to-month
# 9  6388-TABGU  2014-12-01                   No        One year
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида ✔️:**</b>
#
# Ок, есть объединение таблиц. Можно было использовать более короткий вариант - join([таблица1, таблица2....]), для этого предварительно указав индексом cutomerID, который как раз в качестве индекса и подходит.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> буду знать!</div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
#  8   gender            7043 non-null   object
#  9   SeniorCitizen     7043 non-null   int64
#  10  Partner           7043 non-null   object
#  11  Dependents        7043 non-null   object
#  12  InternetService   5517 non-null   object
#  13  OnlineSecurity    5517 non-null   object
#  14  OnlineBackup      5517 non-null   object
#  15  DeviceProtection  5517 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated(subset='customerID')]
# Out:
# Empty DataFrame
# Columns: [customerID, BeginDate, EndDate, Type, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, gender, SeniorCitizen, Partner, Dependents, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, MultipleLines]
# Index: []

# %% [markdown]
# Значит все строки уникальные

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида ✔️:**</b>
#
# Ок, продолжаем исследование!
# </div>

# %% [markdown]
# Переименуем столбцы:

# %%
#df=df.rename(columns={'customerID':'customer_id','BeginDate':'begin_date','EndDate':'end_date',
#            'Type':'type','PaperlessBilling':'paperless_billing','PaymentMethod':'payment_method',
#            'MonthlyCharges':'monthly_charges','TotalCharges':'total_charges',
#            'SeniorCitizen':'senior_citizen','Partner':'partner',
#            'Dependents':'dependents','InternetService':'internet_service','OnlineSecurity':'online_security',
#            'OnlineBackup':'online_backup','DeviceProtection':'device_protection','TechSupport':'tech_support',
#            'StreamingTV':'streaming_tv','StreamingMovies':'streaming_movies','MultipleLines':'multiple_lines'})

# %%
df = clean_columns(df)
# Out:
# 19 column names have been cleaned

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида ✔️:**</b>
#
# Ух сколько кода! В целом ок, но на будущее - если есть возможность использовать промышленные стандарты (те библиотеки, которые обычно используют разработчики и исследователи) - лучшие применять их, а не изобретать велосипед. Нужно облегчить чтение кода другими исследователями, им проще не заглядывать в твои касомные функции.
#
# Кстати, есть неплохая библиотека для выполнения  рутинных операций в пандасе - https://pypi.org/project/skimpy/. Там же есть функция clean_column() котороая в одно действие выполняет приведение названий колонок к соответствующему виду.
#
#
# Рекомендую ознакомиться.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Круто, спасибо!</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v2 ✔️:**</b>
#
# 👌
# </div>

# %%
df.head()
# Out:
#   customer_id  begin_date             end_date            type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   paperless_billing             payment_method  monthly_charges total_charges  \
# 0               Yes           Electronic check            29.85         29.85
# 1                No               Mailed check            56.95        1889.5
# 2               Yes               Mailed check            53.85        108.15
# 3                No  Bank transfer (automatic)            42.30       1840.75
# 4               Yes           Electronic check            70.70        151.65
#
#    gender  senior_citizen partner dependents internet_service online_security  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7043 non-null   object
#  1   begin_date         7043 non-null   object
#  2   end_date           7043 non-null   object
#  3   type               7043 non-null   object
#  4   paperless_billing  7043 non-null   object
#  5   payment_method     7043 non-null   object
#  6   monthly_charges    7043 non-null   float64
#  7   total_charges      7043 non-null   object
#  8   gender             7043 non-null   object
#  9   senior_citizen     7043 non-null   int64
#  10  partner            7043 non-null   object
#  11  dependents         7043 non-null   object
#  12  internet_service   5517 non-null   object
#  13  online_security    5517 non-null   object
#  14  online_backup      5517 non-null   object
#  15  device_protection  5517 non-null   object
# ...

# %% [markdown]
# Изменим тип данных столбца 'total_charger', т.к. признак определяет количество потраченных денег на услуги. Здесь возникла проблема, что некоторые рецепты в этом признаке не имеют чисел. Надо узнать, какие это строки и заполнить их числами.

# %%
df[df['total_charges']==' ']
# Out:
#      customer_id  begin_date end_date      type paperless_billing  \
# 488   4472-LVYGI  2020-02-01       No  Two year               Yes
# 753   3115-CZMZD  2020-02-01       No  Two year                No
# 936   5709-LVOEQ  2020-02-01       No  Two year                No
# 1082  4367-NUYAO  2020-02-01       No  Two year                No
# 1340  1371-DWPAZ  2020-02-01       No  Two year                No
# 3331  7644-OMVMY  2020-02-01       No  Two year                No
# 3826  3213-VVOLG  2020-02-01       No  Two year                No
# 4380  2520-SGTTA  2020-02-01       No  Two year                No
# 5218  2923-ARZLG  2020-02-01       No  One year               Yes
# 6670  4075-WKNIU  2020-02-01       No  Two year                No
# 6754  2775-SEFEE  2020-02-01       No  Two year               Yes
#
#                  payment_method  monthly_charges total_charges  gender  \
# 488   Bank transfer (automatic)            52.55                Female
# ...

# %% [markdown]
# т.к. данные клиенты начали пользоваться услугами 1 ферваля, то скорее всего они оплатили ежемесячную трату, поэтому изменим пустую строку на их месячную трату.

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида ✔️:**</b>
#
# Отлично, есть работа с пропусками. Отлично что определил причину их возникновения. Да, заполнение возможно как средним месяцем, так и 0. Так же допустимо просто удалить строки с пропусками - их у нас не много.
# </div>

# %%
#df['total_charges'][488]='52.55'
#df['total_charges'][753]='20.25'
#df['total_charges'][936]='80.85'
#df['total_charges'][1082]='25.75'
#df['total_charges'][1340]='56.05'
#df['total_charges'][3331]='19.85'
#df['total_charges'][3826]='25.35'
#df['total_charges'][4380]='20'
#df['total_charges'][5218]='19.70'
#df['total_charges'][6670]='73.35'
#df['total_charges'][6754]='61.90'

# %% [markdown]
# <div class="alert alert-warning">
# <b>**Комментарий тимлида ⚠️:**</b>
#
# Так как ты это сделал выше лучше не делать. Сделать замену парой строчек кода, похожих на это
#
# `idx = df_copy[df_copy['total_charges']==' '].index
# df_copy.loc[idx, 'total_charges'] = df_copy.loc[idx, 'monthly_charges']`
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправил снизу.</div>

# %%
idx = df[df['total_charges']==' '].index
df.loc[idx, 'total_charges'] = df.loc[idx, 'monthly_charges']

# %%
df['total_charges']=df['total_charges'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7043 non-null   object
#  1   begin_date         7043 non-null   object
#  2   end_date           7043 non-null   object
#  3   type               7043 non-null   object
#  4   paperless_billing  7043 non-null   object
#  5   payment_method     7043 non-null   object
#  6   monthly_charges    7043 non-null   float64
#  7   total_charges      7043 non-null   float64
#  8   gender             7043 non-null   object
#  9   senior_citizen     7043 non-null   int64
#  10  partner            7043 non-null   object
#  11  dependents         7043 non-null   object
#  12  internet_service   5517 non-null   object
#  13  online_security    5517 non-null   object
#  14  online_backup      5517 non-null   object
#  15  device_protection  5517 non-null   object
# ...

# %%
df.describe()
# Out:
#        monthly_charges  total_charges  senior_citizen
# count      7043.000000    7043.000000     7043.000000
# mean         64.761692    2279.798992        0.162147
# std          30.090047    2266.730170        0.368612
# min          18.250000      18.800000        0.000000
# 25%          35.500000     398.550000        0.000000
# 50%          70.350000    1394.550000        0.000000
# 75%          89.850000    3786.600000        0.000000
# max         118.750000    8684.800000        1.000000

# %%
df.head()
# Out:
#   customer_id  begin_date             end_date            type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   paperless_billing             payment_method  monthly_charges  \
# 0               Yes           Electronic check            29.85
# 1                No               Mailed check            56.95
# 2               Yes               Mailed check            53.85
# 3                No  Bank transfer (automatic)            42.30
# 4               Yes           Electronic check            70.70
#
#    total_charges  gender  senior_citizen partner dependents internet_service  \
# 0          29.85  Female               0     Yes         No              DSL
# ...

# %% [markdown]
# ### Заполнение пропусков

# %% [markdown]
# Пропуски по признакам таблицы internet показывают, что не все клиенты пользуются услугами 'интернет'. Также пропуски по признаку телефонии означают, что не все клиенты пользуются услугой телефонии.
# Возьмем клиента по индексу 0: клиент пользуется услугами интернет, но данных по телефонии у него нет. Значит он является клиентом компании. При этом раз его нет в таблицы телефонии, то он не пользуется услугой телефонии.
# Значит все эти пропуски можно заменить на 'No'

# %%
df['multiple_lines']=df['multiple_lines'].fillna('No phone')
df=df.fillna('No')

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида ✔️:**</b>
#
# Да, все верно. У тебя есть бинарные признаки (Yes/No) и в случае добавления к ним еще одного значения, например Unknown или NA модель может запутаться.  Получается что бинарные признаки превратятся уже не в бинарные, а в обычные номинальные - с тремя категориями: NAN, Yes, No. В чем разница для модели NAN и No? Хорошо что меняешь именно на No.
#
# Но тут есть момент - в столбце `multiple_lines` есть значения Yes/No. Получается столбец говорит о наличии разного типа подключения к телефонии. При объединении таблиц, в данном столбце появляются пропуски, которые говорят о том, что у клиента НЕТ услуг телефонии вообще. Заполняя данный столбец No ты приравниваешь клиентов с телефонией-одна линия, с клиентами у которых вообще нет телефона.  Думаю это не сильно повлияет на качество модели, но держать в голове это стоит.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Может тогда в столбце `multiple_lines` есть смысл ввести третий признак "No lines", например?</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v2 ✔️:**</b>
#
# Да, верно, или "No phone".
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента_2:</b> Сделал</div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7043 non-null   object
#  1   begin_date         7043 non-null   object
#  2   end_date           7043 non-null   object
#  3   type               7043 non-null   object
#  4   paperless_billing  7043 non-null   object
#  5   payment_method     7043 non-null   object
#  6   monthly_charges    7043 non-null   float64
#  7   total_charges      7043 non-null   float64
#  8   gender             7043 non-null   object
#  9   senior_citizen     7043 non-null   int64
#  10  partner            7043 non-null   object
#  11  dependents         7043 non-null   object
#  12  internet_service   7043 non-null   object
#  13  online_security    7043 non-null   object
#  14  online_backup      7043 non-null   object
#  15  device_protection  7043 non-null   object
# ...

# %% [markdown]
# Пропусков больше нет.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Объединили 4 таблицы в одну. В этой таблицы заменили имя признаков на принятые нормы синтаксиса. Пропуски заменили на 'No', что означает отсутствие услуги у клиента.
# Про данные: существует 2 количественных признака, остальные - категориальные или уникальные. Всего 7043 уникальных клиентов.
# С данными можно работать

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида ✔️:**</b>
#
# Отлично, с данными ознакомился и убедился что как минимум представленные данные содержат какую-то информацию (не пустые и не откровенный мусор). С ними можно начинать работать более серезьно - проводить полноценный исследовательский анализ и выявлять возможные проблемы в данных.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>**Комментарий тимлида ❌:**</b>
#
# В соответствии с заданием на данном этапе тебе необходимо сформулировать вопросы к тимлиду (или заказчику) по итогам ознакомления с данными и описанием проекта. Я ожидаю увидеть от тебя вопросы, ответы на которые нужны тебе как исследователю, ответы на которые позволят тебе выполнить исследование. Пожалуйста по результатам предварительного ознакомления с данными и описанием проекта подумай и напиши:
#
# - Какие вопросы у тебя возникли по итогам ознакомления с данными? Все ли понятно?
# - Какой информации тебе не хватает для того чтобы выполнить проект?
#
# Сформулируй пожалуйста вопросы и вышли обновленную тетрадку на проверку. Если вопросов нет - напиши "Уточняющих вопросов нет".
# </div>

# %% [markdown]
# ### Уточняющие вопросы

# %% [markdown]
# По ознакомлению с данными все понятно.
# Вопрос по проекту: правильно понимаю, что модель должна предсказывать хочет ли уйти клиент на сегодняшний момент времени?
# 2й вопрос уже задавал по столбцу `multiple_lines`: лучше ввести третий признак клиентов, у которых нет телефона, или оставить два признака?

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v2 ✔️:**</b>
#
# 1. Верно, модель предсказывает уйдет ли клиент на момент выгрузки (или даты, которую мы поставим в качестве даты выгрузки)
# 2. Ответил выше.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v2 ✔️:**</b>
#
# Есть план, есть уточняющие вопросы, (вернее их не осталось), есть предварительное исследование данных.
#
# Отлично, работу приниаю, переходи к следующему этапу исследования - разработка модели.
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# 'end_date' - целевой признак, который указывает либо дату оканчания пользования услугами, либо слово "нет". Предлагаю создать создать на основе этого столбца другой целевой признак "is_end", в котором будет два бинарных признака - 1, которая означает, что клиент закончил пользоваться услугами. И 0 - остался пользоваться этим оператором связи.
#
# Это делается потому, что модель будет предсказывать собирается ли пользователь уйти от оператора(булево значение), а не предсказывать дату окончания использования услуг.

# %%
df['is_end'] = 1

# %%
df.loc[df[df['end_date']=='No'].index,'is_end'] = 0

# %% [markdown]
# Также предлагаю добавить признак количества месяцев использования услуг. Тогда столбец 'begin_date' можем не включать в признаки для обучения модели.

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v3 ✔️:**</b>
#
# Отлично, целевой признак создан!
# </div>

# %%
df['days_count'] = 1
#подсчет количество дней для уходящих и неуходящих клиентов
df.loc[df[df['end_date'] == 'No'].index,'days_count'] = (datetime.strptime('2020-02-01', '%Y-%m-%d') - pd.to_datetime(df['begin_date'])).dt.days
df.loc[df[df['end_date'] != 'No'].index,'days_count'] = (pd.to_datetime(df[df['end_date'] != 'No']['end_date']) - pd.to_datetime(df['begin_date'])).dt.days

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v3 ✔️:**</b>
#
# Отлично, создан новый синтетический признак!
# </div>

# %% [markdown]
# Теперь попробуем составить портрет уходящего клиента

# %%
df.describe()
# Out:
#        monthly_charges  total_charges  senior_citizen       is_end  \
# count      7043.000000    7043.000000     7043.000000  7043.000000
# mean         64.761692    2279.798992        0.162147     0.265370
# std          30.090047    2266.730170        0.368612     0.441561
# min          18.250000      18.800000        0.000000     0.000000
# 25%          35.500000     398.550000        0.000000     0.000000
# 50%          70.350000    1394.550000        0.000000     0.000000
# 75%          89.850000    3786.600000        0.000000     1.000000
# max         118.750000    8684.800000        1.000000     1.000000
#
#         days_count
# count  7043.000000
# mean    985.996166
# std     747.587844
# min       0.000000
# 25%     273.000000
# 50%     883.000000
# 75%    1676.000000
# max    2191.000000

# %%
df['is_end'].value_counts(sort=False).plot.bar(figsize=(10,6))

plt.title('Количество уходящих клиентов')
plt.xlabel('ушел или нет')
plt.ylabel('Количество клиентов')

None #убирает лишнюю строчку над графиком

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v3 ✔️:**</b>
#
# Да, есть дисбаланс целевого признака. Есть несколько вариантов в нашем случае:
#
# - ничего не делать тк дисбаланс пограничный на уровне 1:3, ROC-AUC не чуствительна к дисбалансу классов
# - применить сэмплирование
# - воспользоваться встренными средствами балансировки в моделях
#
# Посмотрим какой вариант выберешь ты в итоге.
# </div>

# %% [markdown]
# Отношение неуходящих к уходящим чуть больше, чем 5/2.

# %%
df[df['is_end']==1].days_count.hist(bins=70, figsize=(11, 7), range=(0, 2300))

plt.title('Количество дней пользования услугами уходящих клиентов')
plt.xlabel('Количество дней')
plt.ylabel('Количество клиентов')

None #убирает лишнюю строчку над графиком

# %%
#ящик с усами
df[df['is_end']==1].boxplot('days_count', figsize=(10,6))
plt.ylabel('Количество дней')
plt.ylim(0,100);

# %%
df[df['is_end']==1].days_count.hist(bins=70, figsize=(9, 5), range=(0, 100))

plt.title('Количество дней пользования услугами уходящих клиентов')
plt.xlabel('Количество дней')
plt.ylabel('Количество клиентов')

None #убирает лишнюю строчку над графиком

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v3 ✔️:**</b>
#
# Есть исследование числовых признаков! Очень удачная визуализация, хорошо что изучаешь данные по когортам (ушел/остался).
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>**Комментарий тимлида_v3 ⚠️:**</b>
#
# Важно на графиках приводить дополнительную информацию, добавляя понятные заголовки, подписи осей, так тебе и твоим коллегам будет проще читать визуализацию. Например, если соберёшься делать презентацию и выгрузишь все графики как картинки: меньше работы по их оформлению и проще идентифицировать, не надо при этом долго сверяться с тетрадью.
#
# Этот материал может помочь освежить нюансы с оформлением - https://nagornyy.me/it/vizualizatsiia-dannykh-v-matplotlib/.
#
# </div>

# %% [markdown]
# Если сравнивать по месяцам, то чаще всего клиент уходит после первого месяца пользования услугами. Возможно в первый же месяц требуется предложить специальные условия для удержания. Основная масса(75%) пользуются услугами до 30 месяцев.

# %%
df[df['is_end']==1].type.value_counts(sort=False).plot.bar(figsize=(10,6))

plt.title('Использование типов оплаты уходящих клиентов')
plt.ylabel('Количество клиентов')

None #убирает лишнюю строчку над графиком

# %%
df[df['is_end']==1].type.value_counts(normalize=True)
# Out:
# Month-to-month    0.885500
# One year          0.088818
# Two year          0.025682
# Name: type, dtype: float64

# %% [markdown]
# Уходящий клиент практически всегда пользовался помесячной оплатой - 88%.

# %%
df[df['is_end']==1].monthly_charges.hist(bins=20, figsize=(11, 7), range=(15, 122))

plt.title('Ежемесячные траты на услуги уходящих клиентов')
plt.xlabel('Ежемесячные траты на услуги')
plt.ylabel('Количество клиентов')

None #убирает лишнюю строчку над графиком

# %%
df[df['is_end']==1].monthly_charges.hist(bins=10, figsize=(9, 5), range=(65, 110))

plt.title('Ежемесячные траты на услуги уходящих клиентов')
plt.xlabel('Ежемесячные траты на услуги')
plt.ylabel('Количество клиентов')

None #убирает лишнюю строчку над графиком

# %%
#ящик с усами
df[df['is_end']==1].boxplot('monthly_charges', figsize=(10,6))
plt.ylim(0,200);

# %% [markdown]
# Уходящий клиент в месяц чаще всего тратит от 69 до 105 единиц

# %%
df[df['is_end']==1].total_charges.hist(bins=50, figsize=(11, 7), range=(0, 9000))

plt.title('Всего потрачено денег на услуги уходящих клиентов')
plt.xlabel('Денежные единицы')
plt.ylabel('Количество клиентов')

None #убирает лишнюю строчку над графиком

# %%
df[df['is_end']==1].total_charges.hist(bins=50, figsize=(11, 7), range=(0, 1000))

plt.title('Всего потрачено денег на услуги уходящих клиентов')
plt.xlabel('Денежные единицы')
plt.ylabel('Количество клиентов')

None #убирает лишнюю строчку над графиком

# %%
#ящик с усами
df[df['is_end']==1].boxplot('total_charges', figsize=(10,6))
plt.ylim(0,10000);

# %% [markdown]
# Чаще всего уходящий клиент тратит от 20 до 95 единиц всего и уходит. Мы уже об этом говорили, что клиенты уходят в первый месяц и тратят чаще от 69 до 105 единиц. Основная масса тратят от 100 до 2200 Однако медианное значение равняется 700 единицам.

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v2 ✔️:**</b>
#
# Есть исследование числовых признаков! Очень удачная визуализация, хорошо что изучаешь данные по когортам (ушел/остался).
# </div>

# %%
df[df['is_end']==1].gender.value_counts(sort=False).plot.bar(figsize=(10,6))

plt.title('Частота пола уходящих клиентов')
plt.ylabel('Количество клиентов')

None #убирает лишнюю строчку над графиком

# %%
df[df['is_end']==1].gender.value_counts(normalize=True)
# Out:
# Female    0.502408
# Male      0.497592
# Name: gender, dtype: float64

# %% [markdown]
# Женщин больше среди уходящих клиентов - разница всего в пол процента. Т.к. в данных клиентов около 7000, то я бы сказал, что уходящий клиент может быть и мужчиной, и женщиной. Пол не важен.

# %%
df[df['is_end']==1].senior_citizen.value_counts(sort=False).plot.bar(figsize=(10,6))

plt.title('Наличие пенсионного статуса уходящих клиентов')
plt.ylabel('Количество клиентов')

None #убирает лишнюю строчку над графиком

# %%
df[df['is_end']==1].senior_citizen.value_counts(normalize=True)
# Out:
# 0    0.745318
# 1    0.254682
# Name: senior_citizen, dtype: float64

# %% [markdown]
# Уходящий клиент чаще всего не имеет пенсионного статуса.

# %%
df[df['is_end']==1].partner.value_counts(sort=False).plot.bar(figsize=(10,6))

plt.title('Наличие партнера уходящих клиентов')
plt.ylabel('Количество клиентов')

None #убирает лишнюю строчку над графиком

# %%
df[df['is_end']==1].partner.value_counts(normalize=True)
# Out:
# No     0.642055
# Yes    0.357945
# Name: partner, dtype: float64

# %% [markdown]
# Уходящий клиент чаще всего не имеет партнера

# %%
df[(df['is_end']==1)].dependents.value_counts(sort=False)
# Out:
# No     1543
# Yes     326
# Name: dependents, dtype: int64

# %%
df[df['is_end']==1].dependents.value_counts(sort=False).plot.bar(figsize=(10,6))

plt.title('Наличие иждивенцев уходящих клиентов')
plt.ylabel('Количество клиентов')

None #убирает лишнюю строчку над графиком

# %%
df[df['is_end']==1].dependents.value_counts(normalize=True)
# Out:
# No     0.825575
# Yes    0.174425
# Name: dependents, dtype: float64

# %% [markdown]
# Уходящий клиент чаще всего не имеет иждивенцев

# %%
df[df['is_end']==1].internet_service.value_counts(sort=False).plot.bar(figsize=(10,6))

plt.title('Интернет-сервисы уходящих клиентов')
plt.ylabel('Количество клиентов')

None #убирает лишнюю строчку над графиком

# %%
df[df['is_end']==1].internet_service.value_counts(normalize=True)
# Out:
# Fiber optic    0.693954
# DSL            0.245586
# No             0.060460
# Name: internet_service, dtype: float64

# %% [markdown]
# Уходящий клиент чаще всего пользуется оптоволоконым интернетом.
# Отмечу, что интернетом пользовалось около 93% уходящих клиентов.

# %%
def graf_internet(a):
    df[df['is_end']==1][a].value_counts(sort=False).plot.bar(figsize=(8,4))
    plt.title('{}'.format(a))
    plt.xlabel('Пользуется')
    plt.ylabel('Количество клиентов')

    None #убирает лишнюю строчку над графиком

# %%
internet_services = ['online_security','online_backup','device_protection','tech_support','streaming_tv','streaming_movies']
for i in internet_services:
    graf_internet(i)
    plt.show() # Это строку лучше закинуть в самый конец функции.

# %% [markdown]
# Из интернет услуг чаще всего уходящие клиенты используют подписку телевидения и фильмов.

# %%
df[df['is_end']==1]['multiple_lines'].value_counts(sort=False).plot.bar(figsize=(8,4))
plt.title('{}'.format('multiple_lines'))
plt.xlabel('Пользуется')
plt.ylabel('Количество клиентов')

None

# %% [markdown]
# Можно сказать, что чаще всего у уходящего клиента есть телефония. Но нет разница ведет он несколько линий или нет.

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v3 ✔️:**</b>
#
# Есть исследование категориальных признаков! Визуализация подобрана хорошо, по ней можно выделить определенные паттерны поведения пользователей. Хорошо что изучаешь данные по когортам (ушел/остался).
#
# Можно было ушел/остался выводить на одном графике. Сразу можно было бы увидеть отличие когорт.
# </div>

# %%
interval_cols = ['monthly_charges','total_charges','days_count']
phik_overview = df.phik_matrix(interval_cols=interval_cols)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\phik\data_quality.py:59: UserWarning: The number of unique values of variable customer_id is large: 7043. Are you sure this is not an interval variable? Analysis for pairs of variables including customer_id can be slow.
#   warnings.warn(

# %%
plot_correlation_matrix(phik_overview.values,
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index,
                        vmin=0, vmax=1, color_map="Greens", 
                        title=r"correlation $\phi_K$", 
                        fontsize_factor=1.5, 
                        figsize=(16, 8))
plt.tight_layout()

# %% [markdown]
# Если оценивать влияние на таргет "is_end", то можем сказать, что признак 'gender' никак не влияет на таргет. А значит этот признак нужно не включать в обучающие. Мультиколинеарных признаков с 'is_end' это 'end_date' и 'customer_id', которые является неинформативными признаками.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Представим портрет уходящего клиента:
# * уходит после первого месяца
# * пользуется помесячной оплатой
# * тратит 87 +-18 единиц в месяц
# * тратит 700 +-600 единиц всего
# * не имеет пенсионный статус
# * не имеет партнера
# * не имеет иждивенцев
# * пользуется оптоволоконым интернетом
# * использует подписку телевидения и фильмов
# * пользуется телефонией

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v3 ✔️:**</b>
#
# Хороший подробный исследовательский анализ. Понравились графики - все подписано и аккуратно оформлено.
# Есть общий анализ датасета, есть анализ в разрезе ушел/остался. Есть выводы по этапам исследвоания. Подготовлен портрет уходящего клиента!
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>**Комментарий тимлида_v3 :**</b>
#
# Нет проверки признаков на мультиколинеарностть. Этот этап позволит тебе понять наличие корреляции между обучающими признаками, а так же проверить нет ли утечки или прокси-признака к целевой переменной.
#
# Для анализа всех признаков можно использовать разные инструменты:
#
# - для числовых признаков - обычный df.corr()
# - для оценки влияния признаков на таргет - можно рассмотреть `sklearn.feature_selection.mutual_info_classif`.
# - для оценки мультиколлинеарности обучающих признаков можно использовать  VIF (VIF (Variance Inflation Factor) - https://nesrakonk.ru/variance-inflation-factor/).
#
# Рекомендую использовать библиотеку phik. Она работает как с категориальными так и с числовыми признаками, при этом для нее нет необходимости кодировать данные (т.е. можно выполнять кодирование после разбиения на трейн-тест). Рекомендую вот хорошая статья про исользование phik - https://towardsdatascience.com/phik-k-get-familiar-with-the-latest-correlation-coefficient-9ba0032b37e7?gi=ec24d1aea018
#
# ----
#
# Напоминаю - два признака называются мультиколлинеарными, если они сильно коррелированы/зависимы. Изменения в одном признаке влекут за собой изменения в другом признаке. Мультиколлинеарность влияет на алгоритмы линейной регрессии, логистической регрессии, KNN и Наивного Байеса. В случае использования этих моделей нужно избавляться от мультиколлинеарности (удалять один из признаков) либо применять регуляризацию в моделях. Кроме этого оценка влияния на таргет позволит на раннем этапе выявить возможные проблемы с данными ДО начала обучения.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента_3:</b> Постарался исправить.</div>

# %% [markdown]
# ## Построение моделей

# %%
df.head()
# Out:
#   customer_id  begin_date             end_date            type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   paperless_billing             payment_method  monthly_charges  \
# 0               Yes           Electronic check            29.85
# 1                No               Mailed check            56.95
# 2               Yes               Mailed check            53.85
# 3                No  Bank transfer (automatic)            42.30
# 4               Yes           Electronic check            70.70
#
#    total_charges  gender  senior_citizen  ... internet_service  \
# 0          29.85  Female               0  ...              DSL
# 1        1889.50    Male               0  ...              DSL
# ...

# %%
#неинформативные признаки
delete=['customer_id','begin_date','end_date','is_end','gender']
#признаки
features=df.drop(delete,axis=1)
target = df['is_end']
#разобьем данные на трейн и тест 75:25
features_train, features_test, target_train, target_test = \
train_test_split(features,target,test_size=0.25,random_state=130223,stratify = target)

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v3 ✔️:**</b>
#
# Отлично что удаляешь неинформативные и спорные признаки - 'customerID','EndDate', 'BeginDate'. Касаемо дат - у нас бинарная классификация а не анализ временных рядов. Кроме этого даты могут дать серьезную утечку целевого признака (помогать предсказывать модели правильный ответ)
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>**Комментарий тимлида_v3 ❌:**</b>
#
# 1. Неверный random_state, должен быть random_state=130223 (в разбивке на датасеты и в моделях при обучении).
# 2. У тебя есть дисбаланс целевого признака. Нужно использовать стратификацию при разбиении на выборки. Это позволит сохранить первоначальный дисбаланс целевого признака в выборках.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента_3:</b> Надеюсь я правильно исправил, добавив аргумент stratify в разбиение.</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента_4:</b> Убрал.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>**Комментарий тимлида_v4 ⚠️:**</b>
#
# При разбиении на трейн-тест нужно использовать стратификацию. Верни пожалуйста этот параметр.
#
# </div>

# %% [markdown]
# ### Масштабирование признаков

# %%
numeric = ['monthly_charges','total_charges','days_count']

scaler = StandardScaler()
scaler.fit(features_train[numeric])

features_train[numeric] = scaler.transform(features_train[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_23180\762379398.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_train[numeric] = scaler.transform(features_train[numeric])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_23180\762379398.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_test[numeric] = scaler.transform(features_test[numeric])

# %% [markdown]
# ### Порядковое кодирование

# %%
df.head()
# Out:
#   customer_id  begin_date             end_date            type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   paperless_billing             payment_method  monthly_charges  \
# 0               Yes           Electronic check            29.85
# 1                No               Mailed check            56.95
# 2               Yes               Mailed check            53.85
# 3                No  Bank transfer (automatic)            42.30
# 4               Yes           Electronic check            70.70
#
#    total_charges  gender  senior_citizen  ... internet_service  \
# 0          29.85  Female               0  ...              DSL
# 1        1889.50    Male               0  ...              DSL
# ...

# %%
#категориальные признаки
category = df.columns.drop(delete+numeric)
category
# Out:
# Index(['type', 'paperless_billing', 'payment_method', 'senior_citizen',
#        'partner', 'dependents', 'internet_service', 'online_security',
#        'online_backup', 'device_protection', 'tech_support', 'streaming_tv',
#        'streaming_movies', 'multiple_lines'],
#       dtype='object')

# %%
encoder = OrdinalEncoder(handle_unknown = 'игнорировать')
target_train=target_train.copy()
target_test=target_test.copy()
features_train=features_train.copy()
features_test=features_test.copy()
encoder.fit(features_train[category])
features_train[category] = encoder.transform(features_train[category])
features_test[category] = encoder.transform(features_test[category])

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v3 :**</b>
#
# 1. Кодирование необходимо для большинства моделей. OHE или Label Encoder вполне допустимый вариант. Молодец что проводишь кодированик ПОСЛЕ разбиения на трейн-тест. Как и с масштабированием - обучаем на трейне, преобразовываем как на трейне так и на тесте. Мы не знаем какие данные могут быть в тесте (по факту тест нам как бы недоступен), по этому не должны допускать утечку инфомрации из теста.
#
# 2. Очень хорошо, что используешь промышленный подход - OНE. Не рекомендуется использовать get_dummies(). Если вссе-таки ты планируешь использовать get_dummies() - нужно после кодирования трейн и тест выполнить проверку не поменялись ли местами колонки в датасетах? Правильно ли выполнено кодирование?
#
# ----
# Лучше использовать pipeline. Это очень эффективная и полезная технология, позволяет не ошибаться при подготовке признаков (тренировочных и тестовых), а так же использовать кроссвалидацию для получения правильной метрики модели.
# </div>

# %%
features_train
# Out:
#       type  paperless_billing  payment_method  monthly_charges  total_charges  \
# 6813   2.0                0.0             2.0        -0.555637       0.383458
# 5251   0.0                1.0             3.0         0.147165      -0.865575
# 1199   0.0                0.0             2.0         0.473703      -0.410621
# 1647   0.0                1.0             0.0         0.493593      -0.622744
# 2588   0.0                0.0             2.0        -0.504253      -0.825949
# ...    ...                ...             ...              ...            ...
# 5337   0.0                0.0             3.0        -0.484362      -0.563339
# 3611   2.0                1.0             1.0         1.161587       0.857132
# 3601   0.0                0.0             1.0        -1.478894      -0.526164
# 3925   1.0                0.0             3.0         0.248276       0.167515
# 6668   0.0                1.0             2.0         1.294191       0.754768
#
# ...

# %% [markdown]
# ### Логистическая регрессия

# %%
state = 130223

# %%
model = LogisticRegression(random_state = state)

# %% [markdown]
# <div class="alert alert-danger">
# <b>**Комментарий тимлида_v3 ❌:**</b>
#
# Неверный random_state, должен быть random_state=130223 (в разбивке на датасеты и в моделях при обучении).
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента_3:</b> Исправил</div>

# %%
param_grid = [
    {'penalty' : ['l1', 'l2', 'elasticnet', None],
    'C' : np.logspace(-1,8,50),
    'solver' : ['liblinear','newton-cg'],
    'max_iter' : [100,200,500,1000,1500,2500]
    }
]

clf = GridSearchCV(model, param_grid = param_grid, cv = 5, verbose = True, n_jobs=-2,scoring = ['roc_auc','accuracy'],refit = 'roc_auc')

# %% [markdown]
# <div class="alert alert-warning">
# <b>**Комментарий тимлида_v3 ⚠️:**</b>
#
# Нет необходимости выполнять разбивку на форлы вручную `cv = KFold(n_splits=5, shuffle=False)`
# </div>

# %%
best_clf1 = clf.fit(features_train,target_train)
# Out:
# Fitting 5 folds for each of 2400 candidates, totalling 12000 fits
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [0.83747476        nan 0.83821373 ...        nan        nan        nan]
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [0.79912936        nan 0.79856154 ...        nan        nan        nan]
#   warnings.warn(

# %%
best_clf1.best_score_
# Out:
# 0.8386930945654851

# %%
best_clf1.best_estimator_
# Out:
# LogisticRegression(C=2.947051702551811, random_state=130223, solver='newton-cg')

# %%
best_clf1.best_params_
# Out:
# {'C': 2.947051702551811,
#  'max_iter': 100,
#  'penalty': 'l2',
#  'solver': 'newton-cg'}

# %% [markdown]
# <div class="alert alert-warning">
# <b>**Комментарий тимлида_v3 ⚠️:**</b>
#
# Не нужно переобучать модель заново. После подбора лучших гиперпараметров гридсерч возвращает лучшую модель, обученную на всем датасете.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>**Комментарий тимлида_v3 ❌:**</b>
#
# Неверно считаешь roc_auc_score(). Посмотри документацию, там подробно расписан случай расчета метрики для бинарной классификации. В качестве предсказания нужно подавать ВЕРОЯТНОСТЬ старшего класа.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента_3:</b> Совсем забыл - сейчас исправил. Спасибо!</div>

# %% [markdown]
# ### K-ближайших соседей

# %%
model = KNeighborsClassifier()

# %%
param_grid = [
    {'n_neighbors':range(1,16,2),
     'leaf_size':range(10,60,10)
    }
]

clf2 = GridSearchCV(model, param_grid = param_grid, cv = 5, verbose = 1, n_jobs=-1,scoring = ['roc_auc','accuracy'],refit = 'roc_auc')

# %%
best_clf2 = clf2.fit(features_train,target_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits

# %%
best_clf2.best_params_
# Out:
# {'leaf_size': 10, 'n_neighbors': 15}

# %%
best_clf2.best_score_
# Out:
# 0.8225466819794652

# %% [markdown]
# ### Случайный лес

# %%
model = RandomForestClassifier(random_state = state)

# %%
max_depth = [int(x) for x in np.linspace(start = 1, stop = 45, num = 45)]
param_dist = {'max_depth': max_depth}
rs = RandomizedSearchCV(model, 
                        param_dist, 
                        n_iter = 20, 
                        cv = 5, 
                        verbose = 1, 
                        n_jobs=-1,
                        scoring = 'roc_auc',
                        random_state=state)
rs.fit(features_train,target_train)
rs.best_params_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# {'max_depth': 8}

# %%
rs.best_estimator_
# Out:
# RandomForestClassifier(max_depth=8, random_state=130223)

# %%
rs.best_score_
# Out:
# 0.8602784835088235

# %% [markdown]
# ### LGBMClassifier

# %%
model = LGBMClassifier(random_state=130223)
param_grid = [
    {'n_estimators':range(100,1200,30),
     'max_depth':range(1,60,4)
    }
]
clf3 = RandomizedSearchCV(model, param_grid, cv = 5, verbose = 1, n_jobs=-1,scoring = ['roc_auc','accuracy'],refit = 'roc_auc')
best_clf3=clf3.fit(features_train,target_train)
#predictions_4 = model.predict_proba(features_train)
#predictions4=predictions_4[:,1]
#print(roc_auc_score(target_train,predictions4))
best_clf3.best_score_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# 0.8860971329776361

# %%
best_clf3.best_params_
# Out:
# {'n_estimators': 220, 'max_depth': 45}

# %% [markdown]
# ### CatBoostClassifier

# %%
model = CatBoostClassifier(random_state = 130223,iterations=250,learning_rate=0.5,loss_function='MultiClass',eval_metric='AUC')
param_grid = [
    {'max_depth':range(1,10)}]

# %%
clf4 = GridSearchCV(model, param_grid = param_grid, cv = 3, verbose = 1, n_jobs=-1,scoring = ['roc_auc','accuracy'],refit = 'roc_auc')
best_clf4=clf4.fit(features_train,target_train)
#predictions_4 = model.predict_proba(features_train)
#predictions4=predictions_4[:,1]
#print(roc_auc_score(target_train,predictions4))
best_clf4.best_score_
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 0:	total: 1.81ms	remaining: 451ms
# 1:	total: 3.56ms	remaining: 441ms
# 2:	total: 5.38ms	remaining: 443ms
# 3:	total: 8.11ms	remaining: 499ms
# 4:	total: 10.6ms	remaining: 520ms
# 5:	total: 12.1ms	remaining: 491ms
# 6:	total: 13.6ms	remaining: 472ms
# 7:	total: 15ms	remaining: 455ms
# 8:	total: 16.6ms	remaining: 445ms
# 9:	total: 18.4ms	remaining: 441ms
# 10:	total: 20.5ms	remaining: 446ms
# 11:	total: 22.2ms	remaining: 440ms
# 12:	total: 23.5ms	remaining: 428ms
# 13:	total: 25.1ms	remaining: 423ms
# 14:	total: 26.8ms	remaining: 419ms
# 15:	total: 28.3ms	remaining: 414ms
# 16:	total: 29.9ms	remaining: 409ms
# 17:	total: 31.4ms	remaining: 405ms
# 18:	total: 33ms	remaining: 401ms
# 19:	total: 35.1ms	remaining: 404ms
# 20:	total: 36.8ms	remaining: 402ms
# 21:	total: 39.5ms	remaining: 410ms
# 22:	total: 41.7ms	remaining: 412ms
# 23:	total: 43.3ms	remaining: 408ms
# 24:	total: 44.9ms	remaining: 405ms
# ...

# %%
best_clf4.best_params_
# Out:
# {'max_depth': 3}

# %% [markdown]
# <div class="alert alert-warning">
# <b>**Комментарий тимлида_v3 ⚠️:**</b>
#
# Отлично, есть исследование моделей, получены метрики на кроссвалидации. Не хватает сводной таблицы, по ней будет удобно определить лучшую модель.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>**Комментарий тимлида_v4 ❌:**</b>
#
# Нелья проверять качество работы модели на тех же данных, на которых модель обучается. Это касается всех моделей выше.
#
# `model.fit(features_train,target_train)
# predictions_4 = model.predict_proba(features_train)`
#
# Достаточно собрать метрику  `grid_model.best_score_` со всех моделей, пострить таблицу и выбрать лучшую модель по этой метрике. На ней проверить тестовую выборку и это будет итоговая метрика. Для лучше модели постоить roc-auc кривую, матрицу ошибок и график важности признаков.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента_4:</b> Исправил ниже.</div>

# %% [markdown]
# ### Определение лучшей модели

# %% [markdown]
# Т.к. LGBMClassifier выше других моделей, то она наилучшая

# %%
results = [best_clf1.best_score_,best_clf2.best_score_,rs.best_score_,best_clf3.best_score_,best_clf4.best_score_]
index = ['LogisticRegression','KNeighborsClassifier','RandomForestClassifier','LGBMClassifier','CatBoostClassifier']

best_result = pd.DataFrame(results,index=index,columns=['best_score']).sort_values(by='best_score',ascending=False)
best_result
# Out:
#                         best_score
# LGBMClassifier            0.886097
# CatBoostClassifier        0.883761
# RandomForestClassifier    0.860278
# LogisticRegression        0.838693
# KNeighborsClassifier      0.822547

# %% [markdown]
# Лучшая модель 'CatBoostClassifier'

# %% [markdown]
# <div class="alert alert-danger">
# <b>**Комментарий тимлида_v4 ❌:**</b>
#
# Матрицу ошибок как и ROC-AUC кривую нужно строить и анализировать на тестовой выборке
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента_4:</b> Сделал внизу.</div>

# %% [markdown]
# ## Финальный тест

# %%
predictions = best_clf4.predict_proba(features_test)[:, 1]
print(roc_auc_score(target_test,predictions))
# Out:
# 0.9098317386455026

# %%
predictions = best_clf4.predict(features_test)
print(accuracy_score(target_test,predictions))
# Out:
# 0.8534923339011925

# %% [markdown]
# Модель RandomForestClassifier выдает метрику AUC-ROC = 0.82. Метрика accuracy = 0.78.

# %%
fpr1, tpr1, _ = roc_curve(target_test,predictions)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--',label='ROC кривая (area = 0.5)')
plt.plot(fpr1,tpr1, linestyle='--',label='CatBoostClassifier')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend()
plt.show()

# %% [markdown]
# ### Матрица ошибок

# %%
pred4 = best_clf4.predict(features_test)

# %%
confusion_matrix(target_test,pred4)
# Out:
# array([[1225,   69],
#        [ 189,  278]], dtype=int64)

# %%
conf_matrix_baseline = pd.DataFrame(confusion_matrix(target_test,pred4), index = ['actual 0', 'actual 1'], columns = ['predicted 0', 'predicted 1'])
display(conf_matrix_baseline)
display('CatBoostClassifier recall score', recall_score(target_test,pred4))
# Out:
#           predicted 0  predicted 1
# actual 0         1225           69
# actual 1          189          278
# 'CatBoostClassifier recall score'
# 0.5952890792291221

# %% [markdown]
# Модель может ошибаться в 22% случаев. Наиболее вероятно, что модель будет чаще неверно будет прогнозировать уходящих клиентов, чем неуходящих. Это может привести к тому, что оператор "ошибочным" неуходящим пользователям не будет предлагать промокоды и специальные условия, что может привести к уходу этих клиентов.

# %% [markdown]
# ### Анализ важности признаков

# %%
model = CatBoostClassifier(random_state = 130223,iterations=250,learning_rate=0.5,loss_function='MultiClass',eval_metric='AUC')

# %%
model.fit(features_train,target_train)
# Out:
# 0:	total: 3.91ms	remaining: 974ms
# 1:	total: 6.98ms	remaining: 865ms
# 2:	total: 9.67ms	remaining: 796ms
# 3:	total: 12.8ms	remaining: 789ms
# 4:	total: 17.6ms	remaining: 864ms
# 5:	total: 20.5ms	remaining: 835ms
# 6:	total: 23.2ms	remaining: 807ms
# 7:	total: 24.4ms	remaining: 737ms
# 8:	total: 27.2ms	remaining: 730ms
# 9:	total: 30.1ms	remaining: 722ms
# 10:	total: 33ms	remaining: 716ms
# 11:	total: 36ms	remaining: 715ms
# 12:	total: 39ms	remaining: 712ms
# 13:	total: 42.8ms	remaining: 722ms
# 14:	total: 46.5ms	remaining: 729ms
# 15:	total: 52.9ms	remaining: 773ms
# 16:	total: 56.8ms	remaining: 778ms
# 17:	total: 59.9ms	remaining: 772ms
# 18:	total: 63.6ms	remaining: 773ms
# 19:	total: 67.4ms	remaining: 775ms
# 20:	total: 70.5ms	remaining: 768ms
# 21:	total: 73.6ms	remaining: 763ms
# 22:	total: 77.1ms	remaining: 761ms
# 23:	total: 81.7ms	remaining: 769ms
# 24:	total: 84.9ms	remaining: 764ms
# 25:	total: 88.3ms	remaining: 761ms
# 26:	total: 92ms	remaining: 760ms
# ...

# %%
cat_iris_imp = pd.Series(model.get_feature_importance(),
                         df.drop(delete, axis=1).columns)
fig, ax = plt.subplots(figsize=(16,12))
cat_iris_imp.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность, %')
fig.tight_layout()
None

# %% [markdown]
# Самые важные признаки - "type",'monthly_charges','month_count','total_charges','internet_service'. От них модели нужно отталкиваться при предсказании ухода клиента.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента_2:</b> Добился метрику "auc_roc" = 80% в "случайном лесе". Остальные модели показываю меньше 75%. Скорее всего проблема в обработке данных, но не понимаю что конкретно не так.</div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>**Комментарий тимлида_v3 ❌:**</b>
#
# 1. Не хватает анализа важности признаков итоговой модели. Нужно построить график (barplot) отсортированных по важности признаков и сделать по ним свои выводы.
# 2. Нет графика roc-auc для лучшей модели.
# 3. Нужена матрица ошибок и выводы по ней. С точки зрения метрики - да, все ок, нужный показатель достигнут. Но вот с точки зрения бизнеса - ROC_AUC плохо интерпретируется. Гораздо лучше отразить дополнительно к этому графику еще и матрицу ошибок - confusion matrix. На основе нее сделать выводы как часто может ошибаться, какой тип ошибки наиболее вероятен и к чему с тз бизнеса это может привести.
#
# ----
#
# Метрика улучшится если исправишь расчет ROC-AUC для лучшей модели. Кроме этого рекомендую (если вдруг захочется попробовать еще улучшить метрику) попробовать алгоритмы градиентного бустинга.
#
# В целом не плохая работа, но есть над чем еще поработать. Пожалуйста отработай мои замечания и высылай тетрадку на проверку.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента_3:</b> Постарался все исправить. Но на тестовых данных AUC-ROC все равно не выдает >=0.85. Хотя на трейне модель выдает 0.99. Помимо LightGBM пробовал проверять модель случайного леса, но выдавало значени 0.849. Пытался внимательно смотреть на обработку данных, но ничего не вышло.
# Также попробовал поменять цель проекта - посмотрите, пожалуйста.</div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>**Комментарий тимлида_v4 ❌:**</b>
#
# Работа стала лучше. метрика в 0,99 изза неверного тестирования. Нужно использовать метрику с кроссвалидации и осуществлять подобор гиперпараметров. Но все еще есть серьезные ошибки (тестируешь на тренировочной выборке). Так же рекомендую убрать подготовку фолдов для кроссвалидации - `cv = KFold(n_splits=5, shuffle=False)`. Гридсерч сам умеет разбивать в соответствии с типом задачи. Или как минимум сделать стратификацию при формировании фолдов. Отработай мои замечания (v4) и высылай тетрадку на проверку.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента_4:</b> Исправил. Убрал stratify в train_test_split.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида [КОД ФИНАЛЬНЫЙ] ✔️:**</b>
#
# Андрей, получилось хорошее и качественное исследование!
#
# Обработка данных, размышления над признаками, поиск и сравнение различных вариантов обучающего датасета. Конечные результаты, графика - многое удалось как надо. Можно сказать, что пройден весь алгоритм моделирования от анализа исходной инфо до анализа важности факторов.
# А что совсем хорошо, так это то, что нет гонки за точностью любой ценой, даже ценой наружения бизнес-логики. (это я про даты-признаки - всегда есть соблазн их оставить...)
#
# Прежде, чем пойти дальше хочу обратить особое внимание на следующие пункты:
#
# 1. F1, Accuracy и AUC - отличные метрики, но нужно держать в голове, что это лишь обобщённые характеристики. А в реальной практике бизнесу часто важно знать детали самой ошибки - из каких ошибок/успехов она складывается. И в этом случае очень кстати будут меры полноты и точности. Рассмотри возможность их использования для своих проектов. Только через них можно выйти на финансовые возможности модели. Ведь перед запуском её в бой, будет сравнение стоимости создания и поддержки модели со стомостью "оставить как есть".
#
#
# 2. При анализе факторов влияния (их зависиомть между собой и на целевую) происходит по одному из трёх алгоритмов, исходя из типа шкалы. Могут применять следующие графический и аналитический анализы:
#
# - колличественная-колличественная: аналитически метод - корреляции, графический - скатерплот.
# - колличественная-номинальная: аналитически методод - проверка гипотез (стьюдент), графический - боксплот.
# - номинальная-номинальная: аналитически методод - Хи-квадрат, графический - круговая диаграмма
# Это я к тому разделу, который посвящён анализу данных. Там сделаны интересные предположения и их аналитическая проверка. Очень важные этапы любого исследования, где требуется определить валидность использования признаков из датасета.
#
# 3. Алгоритм нахождения модели может быть таким:
#
# - изучаем проблематику бизнеса и самой темы (в данном случае отток). Пытаемся понять суть явления.
# - генерируем разные факторы влияния - любые.
# - дизайнируем (прикидываем модели) какие методы решения есть, чтобы решить проблему.
# - Смотрим, какие данные и в какой шкале есть. Что нужно ещё, что применить выбранный метод.
# - Оцениваем мультиколлинеарность.
# - Готовим подходящий датасет (масштабируем, убираем лишние признаки, кодируем)
# - Строим модели и анализируем те фактры, какие сгенерировали ранее.
# - Думаем над тем, какие причины (факторы) могут ещё влиять на таргет.
# - Если после нескольких итераций точность "замирает" - значит достигли потолка)
#
# 4. Проведение анализа важности факторов с помощью команды feature_importances_ (+графический анализ). Отличная вещь намечается: высокая метрика + график рейтинаг факторов по силе влияния на целевой признак). Важнейшая часть любого модельного финала. Если видно, что часть факторов - слабозначимые для модели. Т.е. не значительно влияют на целевую переменную, то их смело можно убирать из модели. Ну и для бизнеса доносить: на эти факторы надо обращать внимание, а эти не влияют на уход клиента.
#
# Вопросов у меня больше нет, работу принимаю, твоя метрика ROC-AUC = 0.857 что соответствует ЗАЧЕТУ.
#
# Не забудь перед подготовкой отчета еще раз прочитать мои рекомендации по его составлению (что проверяется и на что обращается внимание при проверке).
#
#
# </div>

# %% [markdown]
# ## Отчет

# %% [markdown]
# ### Вступление

# %% [markdown]
# Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Задача бинарной классификации. Целевой признак – ‘EndDate’, у которого есть две категории значений: дата вида ‘xxxx-xx-xx 00:00:00’, как окончание пользования услугами клиента, и ‘No’, как обозначение, что клиент продолжает пользоваться услугами.
# Метрика ROC-AUC должна быть не меньше 0,85 с помощью окончательного набора данных из 7043 клиентов.

# %% [markdown]
# ### Датасет

# %% [markdown]
# Данные состоят из файлов, полученных из разных источников:
# * contract.csv — информация о договоре;
# * personal.csv — персональные данные клиента;
# * internet.csv — информация об интернет-услугах;
# * phone.csv — информация об услугах телефонии.
# Во всех файлах столбец customerID содержит код клиента.
# Информация о договорах актуальна на 1 февраля 2020.
# Модель будет обучаться на одной таблице, поэтому все таблицы из файлов объединили в одну по столбцу ‘customer_id’. Всего 7043 клиента.

# %% [markdown]
# ### Признаки и предварительная обработка

# %% [markdown]
# Пропуски по признакам таблицы internet показывают, что не все клиенты пользуются услугами 'интернет'. Также пропуски по признаку телефонии означают, что не все клиенты пользуются услугой телефонии. Возьмем клиента по индексу 0: клиент пользуется услугами интернет, но данных по телефонии у него нет. Значит он является клиентом компании. При этом раз его нет в таблицы телефонии, то он не пользуется услугой телефонии. Значит все эти пропуски можно заменить на 'No'. Признак ‘mupltiple_lines’ имел значения ‘Yes’/’No’ – озночало, что клиент либо имеет дополнительные линии, либо нет, при этом эти клиенты пользуются телефонией. Поэтому было принято решение, клиентов, которых не было в таблице телефонии – заменить на новое значение ‘No phone’.
# Также добавили признак ‘month_count’, что означало количество месяцев пользования услугами. Так модели будет проще обучаться, потому что в обучающихся признаков у нее будет количество месяцев вместо начальной даты пользования услугами. Итого получилось 3 количественных признака: 'monthly_charges','total_charges','month_count'.
# Также вместо признака ‘end_date’ целевым признаком стал ‘is_end’, значения которых было два бинарных признака: 1/0. 1 – уход клиента; 0 – клиент продолжает пользоваться услугами.

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# Мы смогли определить дисбаланс классов: уходящих и неуходящих клиентов(примерно 1:3)
# Если сравнивать по месяцам, то чаще всего клиент уходит после первого месяца пользования услугами. Возможно в первый же месяц требуется предложить специальные условия для удержания. Уходящий клиент практически всегда пользовался помесячной оплатой - 88%. Уходящий клиент в месяц чаще всего тратит от 69 до 105 единиц. Основная масса тратят от 100 до 2200 Однако медианное значение равняется 700 единицам. Женщин больше среди уходящих клиентов - разница всего в пол процента. Т.к. в данных клиентов около 7000, то я бы сказал, что уходящий клиент может быть и мужчиной, и женщиной. Пол не важен. Уходящий клиент чаще всего не имеет пенсионного статуса. Уходящий клиент чаще всего не имеет партнера. Уходящий клиент чаще всего не имеет иждивенцев. Уходящий клиент чаще всего пользуется оптоволоконым интернетом. Отмечу, что интернетом пользовалось около 93% уходящих клиентов. Можно сказать, что чаще всего у уходящего клиента есть телефония. Но нет разница ведет он несколько линий или нет. Если оценивать влияние на таргет "is_end", то можем сказать, что признак 'gender' никак не влияет на таргет(рис.1.1). А значит этот признак нужно не включать в обучающие. Мультиколинеарных признаков с 'is_end' это 'end_date' и 'customer_id', которые являются неинформативными признаками.
# ![image.png](attachment:image.png)
# На основе рассуждений представим портрет уходящего клиента:
# * уходит после первого месяца
# * пользуется помесячной оплатой
# * тратит 87 +-18 единиц в месяц
# * тратит 700 +-600 единиц всего
# * не имеет пенсионный статус
# * не имеет партнера
# * не имеет иждивенцев
# * пользуется оптоволоконым интернетом
# * использует подписку телевидения и фильмов
# * пользуется телефонией

# %% [markdown]
# ### Модели

# %% [markdown]
# Мы обучаем Логистическую регрессию, K-ближайших соседей, Случайный лес, LGBMClassifier, CatBoostClassifier, чтобы решить задачу бинарной классификации. Перед обучением удаляем неинформативные признаки 'customer_id','begin_date','end_date','is_end','gender', масштабируем количественные признаки и используем порядковое кодирование(Ordinal Encoder). В обучении Логистической регрессии мы используем параметры регуляризации penalty,проверяя методы 'l1', 'l2', 'elasticnet', None(ничего не стоит в параметре), C, проверяя 50 значений, которые разбиты по равным отрезкам на луче от -1 до 8, параметр solver, проверяя 'liblinear','newton-cg', и параметр max_iter, проверяя значения 100,200,500,1000,1500,2500. Лучшие параметры для этой модели:
# 'C': 15.99858719606059,
#  'max_iter': 100,
#  'penalty': 'l2',
#  'solver': 'newton-cg'
#
# В обучении К-ближайших соседей мы используем параметр n_neighbors, проверяя целый значения от 1 до 15, параметр leaf_size, проверяя значения от 10 до 50, кратные 10. Лучшие параметры для этой модели:
# 'leaf_size': 10,
# 'n_neighbors': 15
#
#
# В обучении случайного леса используем параметр n_estimators, проверяя 250 значений от 100 до 1250, параметр max_features, проверяя методы ‘log2’, ‘sqrt’, параметр max_depth, проверяя 45 значений от 1 до 45. Лучшие параметры для этой модели:
# max_depth=17,
#
# max_features='sqrt',
# min_samples_leaf=10,
#
# min_samples_split=56,
# n_estimators=464,
#
# random_state=130223.
# В обучении LGBMClassifier используем параметр n_estimators, проверяя значения от 100 до 1200 каждое 30е значение в этом диапозоне, параметр max_depth, проверяя значения от 1 до 60 каждое 4е. Лучшие параметры для этой модели:
# 'max_depth': 1,
# 'n_estimators': 490
#
# В обучении CatBoostClassifier используем  параметры iterations=250,learning_rate=0.5,loss_function='MultiClass',eval_metric='AUC' и параметр max_depth, проверяя значения от 1 до 9. Лучшее значение – 1

# %% [markdown]
# ### Результаты

# %% [markdown]
# Ниже приведены результаты для метрики ROC-AUC
# ![image-2.png](attachment:image-2.png)
# В итоге получены следующие экспериментальные данные, представленные на рис. 1. При обучении использовался набор из 5282 строк. Лучшая модель CatBoostClassifier. Полученные результаты подтверждают оправданность применения предложенного подхода к организации процесса машинного обучения для решения задачи бинарной классификации. Достигнуты положительные результаты на тестовых данных(ROC-AUC = 85.2, accuracy = 0.8).

# %% [markdown]
# ### Обсуждение

# %% [markdown]
# В рамках данной статьи рассмотрено большое количество методов машинного обучения, используемых при решении задачи бинарной классификации.
# Смогли получить матрицу ошибок на рис.2, которая говорит о том, что модель может ошибаться в 25% случаев. Наиболее вероятно, что модель будет чаще неверно будет прогнозировать уходящих клиентов, чем неуходящих. Это может привести к тому, что оператор "ошибочным" неуходящим пользователям не будет предлагать промокоды и специальные условия, что может привести к уходу этих клиентов.
# ![image.png](attachment:image.png)
# Самые важные признаки - "type",'monthly_charges','month_count','total_charges','internet_service'. От них модели нужно отталкиваться при предсказании ухода клиента(рис.3)
# ![image-4.png](attachment:image-4.png) рис.3

# %% [markdown]
# ### Ответы на вопросы

# %% [markdown]
# #### Какие пункты плана были выполнены, а какие — нет (поясните почему)?
# Были выполнены все пункты плана:
# 1. Загрузить и подготовить данные.
# 2. Выполнить разведочный анализ: составить портрет уходящего клиента.
# 3. Сделать тестовую выборку размером 25%. Обучить модели с разными гиперпараметрами и выбрать наилучшую.
# 4. Проверить данные на тестовой выборке.
# 5. Сделать отчет по работе.
# #### Какие трудности возникли и как вы их преодолели?
# С исследовательским анализом данных проблем не было. Трудности возникли с преодолением метрики ROC-AUC >= 0.85. Сначала работа была сделана без модели CatBoostClassifier. "Случайный лес" на тестовой выборке без стратификации выдавал нужное значение. Но в работе обязательна стратификация, т.к. присутствует дисбаланс классов. И с введением переменной stratify метрика не могла достичь 0.85. Помогла модель CatBoostClassifier.
# #### Какие ключевые шаги в решении задачи выделили?
# Ключевые шаги в решении считаю созданием таблицы корреляции, использования стратификации, масштабированием и порядковым кодированием и созданием модели CatBoostClassifier, которая помогла добиться нужного результата.

# %% [markdown]
# <div class="alert alert-danger">
# <b>**Комментарий тимлида_v5 ❌:**</b>
#
# Хороший отчет, четкая структура и подача информации - без воды, все по существу. Есть описание предобработки, основых этапов работы, итоговая метрика и параметры модели.
#
# В отчете я не увидел ответов на вопросы задания:
#
# - Какие пункты плана были выполнены, а какие — нет (поясните почему)?
# - Какие трудности возникли и как вы их преодолели?
# - Какие ключевые шаги в решении задачи выделили?
#
# Можно в выводах отчета дать на них ответы отдельным абзацем. Пожалуйста оперативно даделай и высылай на проверку.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида [ФИНАЛЬНЫЙ]✔️:**</b>
#
# Привет Андрей!
#
# Хочу дать тебе обратную связь, как тимлид, по финальному проекту.
#
# В твоей работе мне очень понравилось:
# - Владение инструментарием ДС. По исследованию видно, что ты понимаешь что делаешь, владеешь основным инструментарием, успешно его применяешь и хорошо интерпретируешь результаты. Вижу, что знания, полученные в ходе обучения, уверенно перешли в навыки и стали уже твоими Hard Skills.
# - Кроссвалидация и подбор гиперпараметррв. Круто, что в работе используются инструменты типа GridSearchCV , RandomSearchCV, HalvingGridSearchCV или Optuna. Это  очень мощные инструменты для поиска оптимальных гиперпараметров.
# - Очень здорово, что есть  анализ мультиколлинеарности – отдельно для числовых, отдельно для категориальных признаков. Отлично что ты понимаешь суть коэфициента корреляции Пирсона, Спирмена и хи-квадрат. Мало кто с первого раза это сделали правильно!
#
# Над чем еще можно поработать:
# - Тайминг. Некоторые работы ты сдавал награни дедлайна. Хорошо, что все в итоге получилось сделать до жесткого дедлайна, но в реальной работе лучше до этого не доводить. Настоящая работа - это не подготовка к сдаче экзаменов в сессии, нужно планировать заранее и выполнять работу чуть раньше крайного срока, чтобы было достаточно времени на ее доработку.
# - Немного улучить и причесать код. Повторяющиеся действия можно выделять в отдельную функцию, использовать классы и ООП подход. Это удобнее и нагляднее.  Решение – больше самостоятельной практики, больше изучай чужой код.
# - Кодирование признаков. Нужно освежить в памяти навыки по кодированию признаков - для каких моделей кодирование обязательно, а для каких - нет. Например модели типа CatBoost/XGBoost, LightGBM могут на вход получать "грязные данные", без предварительного кодирования. В некоторых случаях достаточно либо просто выделить (передать в модель) список категориальных признаков, либо предварительно в пандас изменить тип столбцов на 'category'. Кроме этого нужно помнить разницу между OHE и Ordinal(label) Encoding. В каких случаях лучше использовать какой подход к кодированию. На всякий случай вот короткая статья - https://www.naukri.com/learning/articles/one-hot-encoding-vs-label-encoding/. Решение - больше практики при подготовке датасетов с различными типами данных (количественные, номинальные, бинарные признаки).
# - Использование pipeline. Это очень эффективная и полезная технология, позволяет не ошибаться при подготовке признаков (тренировочных и тестовых), а так же использовать кроссвалидацию для получения правильной метрики модели. Рекомендую ознакомиться и использовать в своих работах. Вот ссылки - статья про pipeline и ColumnsTransformer - https://medium.com/mlearning-ai/neat-data-preprocessing-with-pipeline-and-columntransformer-2a0468865b6b. Вот статья про пайплайн и гридсерч - https://towardsdatascience.com/an-introduction-to-building-pipelines-and-using-grid-searches-in-scikit-learn-92ea72f9b5b7
# - Прокачать навыки по визуализации данных, мне кажется можно лучше увидеть  основные закономерности в данных, используя более сложные и интерактивные графики. Это очень полезный инструмент для презентации результатов (часто гораздо эффективнее таблиц).  Решение – почитать про seaborn, plotly, cufflinks  и попрактиковаться с этими инструментами.
# - Отбор признаков. Можно проводить отор признаков, с использованием целого набора инструментов, а не только руководствуясь силой корреляции. Рекомендую ознакомиться со статьей https://medium.com/@hertan06/which-features-to-use-in-your-model-350630a1e31c. Так же метрику можно было сделать побольше, если эксперементировать с другими признаками, например рассматривать длительность не в месяцах а в днях.
# - Оформление исследования и отчет. По каждому блоку работы в описательной части хорошо бы придерживаться схемы – что планируешь делать (гипотеза), что будешь использовать для ее подтверждения или опровержения (используемые методы и алгоритмы), само исследование с краткими пояснениями по каждому результату, общий вывод (подтвердилась гипотеза или нет). У тебя местами это присутствует, но не везде.  Если хочешь добавить данный проект в портфолио – лучше оформить его в соответствии с требованиями к оформлению проекта. В текущем виде его сложно читать человеку, не погруженному в тему исследования. Решение – еще раз освежить в памяти раздел обучения, где рассказывается о том, как оформлять проект. Примеры хороших отчетов можно посмотреть на  сайте Stanford University ( http://cs229.stanford.edu/projects2014.html ). Это отчеты по финальным проектам направления Machine Learning. Изучая их становится понятно наполнение отчета по исследованию, а так же, что главное - понятна сама структура отчета.
#
# Позади большой путь освоения новой специальности! Решение поставленной задачи в рамках финального проекта показало, что у тебя достаточно знаний и навыков для выполнения исследовательских работы в области ДС как минимум на уровне Джуна. Не останавливайся на достигнутом – изучай новые методы и подходы, практикуйся в решении различных задач (куча задач есть на Kaggle). Рекомендую очень серьезно и обстоятельно готовиться к собеседованиям, это тоже очень важная часть процесса трудоустройства.
#
# Еще раз поздравляю тебя с завершением учебы! Желаю скорейшего трудоустройства и успехов в новой профессии! Главное – это заниматься тем, что тебе нравится!
#
# </div>
